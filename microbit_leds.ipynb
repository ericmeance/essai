# %% [markdown]
# # A- Debuter avec les cartes microbits
# La manière traditionnelle de commencer la programmation dans un nouveau langage est de demander à votre ordinateur de dire « Hello, World ! ».
# C’est facile avec MicroPython :

# %% [markdown]
# On peut aussi faire apparaître des images. Essayer le code ci-dessous

# %%
from microbit import*
display.scroll("Hello, World!")

# %%
from microbit import *// importer la totalité de la librairie «microbit»
display.show(Image.HAPPY)

# %% [markdown]
# Modifier le programme pour faire apparaitre d'autres images.Voici la liste des images intégrées :

# %% [markdown]
# ![type_image.JPG](attachment:type_image.JPG)

# %% [markdown]
# Essayer ensuite le programme suivant. Sur votre compte rendu, indiquer ce qu'il fait et puis ce qui pourrait être plus intérssant à faire.

# %%
from microbit import*
display.show(Image.HAPPY)
sleep(500)
display.show(Image.ANGRY)
sleep(500)

# %% [markdown]
# Essayer ensuite le programme suivant et indiquer ce qu'il fait. Modifier ce programme pour la première image continue à s'afficher.
#
# Copier le code modifié sur votre compte rendu.

# %%
from microbit import*
display.show(Image.HAPPY)
while true :
    display.show(Image.HEART)
    sleep(500)
    display.show(Image.ANGRY)
    sleep(500)

# %% [markdown]
# ### 1-Allumer des leds

# %% [markdown]
# On va maintenant allumer les leds de façon individuelle. Copier le code ci dessous sur Mu editor et flasher le sur la carte microbit. Indiquer ensuite ce qui se passe sur la carte et faire le lien avec le code.

# %%
from microbit import*
display.set_pixel(0,2,9)
display.set_pixel(1,2,9)
display.set_pixel(2,2,9)
display.set_pixel(3,2,9)
display.set_pixel(4,2,9)

# %% [markdown]
# Copier le code ci dessous sur Mu editor et flasher le sur la carte microbit. Que voit-on sur la carte. Expliquer le fonctionnement de la boucle **while**.

# %%
from microbit import*
i = 0 
while i <5 :    
    display.set_pixel(i, 2, 9)
    i=i+1

# %% [markdown]
# Tester maintenant le code ci dessous. Qu'est ce qui a changé ? Quelle est la différence avec le code précédent?
#
# Vocabulaire : le fait qu'une ligne de code soit décalée à droite par rapport à la précédente, s'appelle **l'indentation**.

# %%
from microbit import*
i = 0 
while i <5 :    
    display.set_pixel(i, 2, 9)
i=i+1

# %% [markdown]
# Dernier test avec le code ci dessous. Que se passe-t-il? Expliquer.(utiliser le bouton vérifier de Mu editor)

# %%
from microbit import*
while i <5 :    
    display.set_pixel(i, 2, 9)
    i=i+1

# %% [markdown]
# ![image_leds-ConvertImage.jpg](attachment:image_leds-ConvertImage.jpg)
#
#
# Créer le code pour faire apparaitre les leds comme sur la photo. Attention, elles sont d'intensités différentes.

# %% [markdown]
# ### 2-Allumer des leds les unes après les autres

# %% [markdown]
# Regarder la [vidéo](https://www.pearltrees.com/emeance/programmmation-carte-microbit/id27111601/item272442464) et retrouver le code permettant d'afficher la séquence d'allumage de led vue dans cette vidéo.
#
# Tester le programme et coller le sur votre compte rendu une fois réussi.

# %% [markdown]
# regarder cette autre [vidéo](https://www.pearltrees.com/emeance/programmmation-carte-microbit/id27111601/item272448505) et retrouver le code permettant d'afficher la séquence d'allumage de led vue dans cette vidéo.
#
# Tester le programme et coller le sur votre compte rendu une fois réussi.
